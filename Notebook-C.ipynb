# %%
# Display a hello message in Notebook C
# Display a hello message in Notebook C
# Display a hello message in Notebook C
# Display a hello message in Notebook C
display(spark.createDataFrame([("Hello from Notebook C",)], ["message"]))
